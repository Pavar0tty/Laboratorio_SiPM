# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
from scipy.stats import chi2, norm, cauchy
from iminuit import Minuit
from iminuit.cost import LeastSquares
# Cambiare directory per spostarsi nella cartella principale
import os
while not os.getcwd().endswith('Laboratorio_SiPM'):
    os.chdir('..')

import sys
sys.path.append('Config')
from lablib import *

# %%
Na_L_1 = 0.4083489863383826
Co_L = 0.3877784044468422
Na_C_1 = 0.1688552953715196
Co_C = 0.22416334513568562
Na_B_1 = 0.24980277076150295 
Na_B_2 = 0.16713200286289231
Co_B = 1.0115751908967145

# %%
fig, ax = plt.subplots(1, 1, figsize=(30, 6))
plt.plot((122, 511), (Co_L, Na_L_1), color = 'blue', label = 'risoluzione LySO', marker = 'o')
plt.plot((122, 511), (Co_C, Na_C_1), color = 'red', label = 'risoluzione CsI')
plt.plot((122, 511, 1275), (Co_B, Na_B_1, Na_B_2), color = 'green', label = 'risoluzione BGO')
